# %% [markdown]
# ## SEDフォルダの中身の確認
# SEDフォルダには接頭字SEDからはじまるものと、SRBから始まるものがあります。
# SEDファイルには成績データ、SRBについては成績レースデータが記録されています。
# 仕様は以下です。
# ### SED
# http://www.jrdb.com/program/Sed/sed_doc.txt
#
# ### SRB
# http://www.jrdb.com/program/Srb/srb_doc.txt

# %%
# import modules
from jrdb import load
from jrdb import parse
import os
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
# load text data (ex. SED)
loader = load.FileLoader()
data_dir = 'data/SED_2022'
filename = 'SED220105.txt'
text_data = loader.load(os.path.join(data_dir, filename))

# parse
parser = parse.JrdbDataParser()
df = parser.parse(text_data, 'SED', is_japanese=True)   # return pandas DataFrame

# %%
# load text data (ex. SED)
loader = load.FileLoader()
data_dir = 'data/KYI_2022'
filename = 'KYI220105.txt'
text_data = loader.load(os.path.join(data_dir, filename))

# parse
parser = parse.JrdbDataParser()
df = parser.parse(text_data, 'SED', is_japanese=True)   # return pandas DataFrame
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# c:\Users\rebor\jrdb\test.ipynb セル 4 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/rebor/jrdb/test.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> # parse
#       <a href='vscode-notebook-cell:/c%3A/Users/rebor/jrdb/test.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a> parser = parse.JrdbDataParser()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rebor/jrdb/test.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> df = parser.parse(text_data, 'SED', is_japanese=True)   # return pandas DataFrame
#
# File c:\Users\rebor\jrdb\jrdb\parse.py:17, in JrdbDataParser.parse(self, text_data, data_type, is_japanese)
#      15 config_json = self._loader.load(config_json_name)
#      16 converter = JrdbTextConverterIntoDataFrame(text_data, config_json)
# ---> 17 df = converter.convert_text_into_dataframe()
#      18 formater = JrdbDataFrameFormatter(df, config_json)
#      19 return formater.format_dataframe(is_japanese)
#
# File c:\Users\rebor\jrdb\jrdb\parse.py:30, in JrdbTextConverterIntoDataFrame.convert_text_into_dataframe(self)
#      28 def convert_text_into_dataframe(self):
#      29     df = self._generate_dataframe_for_data_strage()
# ---> 30     return self._store_data(df)
#
# File c:\Users\rebor\jrdb\jrdb\parse.py:44, in JrdbTextConverterIntoDataFrame._store_data(self, df)
#      40 for key in self._keys:
#      41     # if key == "horse_name":
#      42     #     import pdb; pdb.set_trace()
#      43     for row in range(len(df)):
# ---> 44         text_segment = self._text_data[row].encode('shiftjis')[
#      45             self._config_json[key]["start_ind_b"] : self._config_json[key]["end_ind_b"]
#      46         ].decode('shiftjis', errors='ignore')
#      47         df.at[row, key] = text_segment
#      48 return df
#
# UnicodeEncodeError: 'shift_jis' codec can't encode character '\u3231' in position 372: illegal multibyte sequence

# %%
df
# Out:
#         レースキー 場コード   年  回  日   R  馬番            競走成績キー    血統登録番号       年月日  \
# 0    06221101   06  22  1  1   1   1  1910217320220105  19102173  20220105
# 1    06221101   06  22  1  1   1   2  1910428820220105  19104288  20220105
# 2    06221101   06  22  1  1   1   3  1910612720220105  19106127  20220105
# 3    06221101   06  22  1  1   1   4  1910354220220105  19103542  20220105
# 4    06221101   06  22  1  1   1   5  1910194320220105  19101943  20220105
# ..        ...  ...  .. .. ..  ..  ..               ...       ...       ...
# 316  07221112   07  22  1  1  12  12  1710157120220105  17101571  20220105
# 317  07221112   07  22  1  1  12  13  1810489420220105  18104894  20220105
# 318  07221112   07  22  1  1  12  14  1710133420220105  17101334  20220105
# 319  07221112   07  22  1  1  12  15  1811001520220105  18110015  20220105
# 320  07221112   07  22  1  1  12  16  1710338120220105  17103381  20220105
#
#      ... 天候コード   コース レース脚質    単勝    複勝     本賞金 収得賞金 レースペース流れ 馬ペース流れ 4角コース取り
# 0    ...     1  None     3  None  None     0.0    0       33     33       1
# 1    ...     1  None     3  None  None    78.0    0       33     33       3
# 2    ...     1  None     4  None  None     0.0    0       33     33       3
# 3    ...     1  None     2  None   170   130.0    0       33     33       1
# 4    ...     1  None     4  None  None     0.0    0       33     33       1
# ..   ...   ...   ...   ...   ...   ...     ...  ...      ...    ...     ...
# 316  ...     1  None     3  None  None     0.0    0       32     23       3
# 317  ...     1  None     1  1530   300  1110.0  600       32     32       2
# 318  ...     1  None     3  None  None     0.0    0       32     23       3
# 319  ...     1  None     2  None   110   440.0    0       32     32       2
# 320  ...     1  None     2  None  None     0.0    0       32     23       3
#
# [321 rows x 84 columns]

# %%
data_dir = 'data/SED_2022'

# get list of file names in directory
file_names = os.listdir(data_dir)

# filter file names to those starting with 'SED' and ending with '.txt'
sed_file_names = [f for f in file_names if f.startswith('SED') and f.endswith('.txt')]

# load text data and parse into data frames
dfs = []
for file_name in tqdm(sed_file_names):
    loader = load.FileLoader()
    text_data = loader.load(os.path.join(data_dir, file_name))
    parser = parse.JrdbDataParser()
    df = parser.parse(text_data, 'SED', is_japanese=True)
    dfs.append(df)

# concatenate data frames into one
SED_df = pd.concat(dfs, ignore_index=True)
# Out:
#   0%|          | 0/109 [00:00<?, ?it/s]
# 100%|██████████| 109/109 [07:01<00:00,  3.87s/it]

# %%
# # get list of file names in directory
# file_names = os.listdir(data_dir)

# # filter file names to those starting with 'SED' and ending with '.txt'
# sed_file_names = [f for f in file_names if f.startswith('KYI') and f.endswith('.txt')]

# # load text data and parse into data frames
# dfs = []
# for file_name in tqdm(sed_file_names):
#     loader = load.FileLoader()
#     text_data = loader.load(os.path.join(data_dir, file_name))
#     parser = parse.JrdbDataParser()
#     df = parser.parse(text_data, 'SRB', is_japanese=True)
#     dfs.append(df)

# # concatenate data frames into one
# SRB_df = pd.concat(dfs, ignore_index=True)

# %%
SED_df
# Out:
#           レースキー 場コード   年  回  日   R  馬番            競走成績キー    血統登録番号       年月日  \
# 0      06221101   06  22  1  1   1   1  1910217320220105  19102173  20220105
# 1      06221101   06  22  1  1   1   2  1910428820220105  19104288  20220105
# 2      06221101   06  22  1  1   1   3  1910612720220105  19106127  20220105
# 3      06221101   06  22  1  1   1   4  1910354220220105  19103542  20220105
# 4      06221101   06  22  1  1   1   5  1910194320220105  19101943  20220105
# ...         ...  ...  .. .. ..  ..  ..               ...       ...       ...
# 47706  09226912   09  22  6  9  12  12  1810522320221228  18105223  20221228
# 47707  09226912   09  22  6  9  12  13  1710613720221228  17106137  20221228
# 47708  09226912   09  22  6  9  12  14  1710046120221228  17100461  20221228
# 47709  09226912   09  22  6  9  12  15  1810638920221228  18106389  20221228
# 47710  09226912   09  22  6  9  12  16  1910618420221228  19106184  20221228
#
#        ... 天候コード   コース レース脚質    単勝    複勝    本賞金 収得賞金 レースペース流れ 馬ペース流れ 4角コース取り
# 0      ...     1  None     3  None  None    0.0    0       33     33       1
# 1      ...     1  None     3  None  None   78.0    0       33     33       3
# 2      ...     1  None     4  None  None    0.0    0       33     33       3
# 3      ...     1  None     2  None   170  130.0    0       33     33       1
# 4      ...     1  None     4  None  None    0.0    0       33     33       1
# ...    ...   ...   ...   ...   ...   ...    ...  ...      ...    ...     ...
# 47706  ...     1     4     4  None  None    0.0    0       22     22       4
# 47707  ...     1     4     3  None  None    0.0    0       22     22       5
# 47708  ...     1     4     4  None  None    0.0    0       22     22       4
# 47709  ...     1     4     4  None  None    0.0    0       22     22       5
# 47710  ...     1     4     3  None  None    0.0    0       22     22       5
#
# [47711 rows x 84 columns]

# %%
# SRB_df

# %%
# # merge SED_df and SRB_df on multiple columns
# merged_df = pd.merge(SED_df, SRB_df, on=['レースキー', '場コード', '年', '回', '日', 'R'], how='left')

# %%
# merged_df

# %%
# path/to/data/train/直下にSED_2022.csvとして保存
SED_df.to_csv('train_data/SED_2022.csv', index=False)

# %%
SED_df = pd.read_csv('train_data/SED_2022.csv')
# Out:
# C:\Users\rebor\AppData\Local\Temp\ipykernel_6740\958351361.py:1: DtypeWarning: Columns (0,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   SED_df = pd.read_csv('train_data/SED_2022.csv')

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# 目的変数の作成
# 3着以内を1、それ以外を0とする
# '着順'カラムを使用

SED_df['target'] = SED_df['着順'].apply(lambda x: 1 if x <= 3 else 0)

categorical_columns = ['レースキー', '日', '年月日', '馬名', '条件', 'グレード', 'レース名', 'レース名略称', '騎手名', '調教師名', 'レースペース', '馬ペース', '1(2)着馬名']

# 各カテゴリカル列を文字列型に変換し、ラベルエンコーディングを適用
SED_df[categorical_columns] = SED_df[categorical_columns].apply(lambda col: LabelEncoder().fit_transform(col.astype(str)))

# 日付でソートし、最新の20%をテストデータとする
# '年月日'カラムを使用
SED_df['年月日'] = pd.to_datetime(SED_df['年月日'])
SED_df = SED_df.sort_values(by='年月日')
train_SED_df = SED_df.iloc[:int(len(SED_df) * 0.8)]
test_SED_df = SED_df.iloc[int(len(SED_df) * 0.8):]

# 不要なカラムの削除
# '着順'と'年月日'カラムを削除
train_SED_df = train_SED_df.drop(['着順', '年月日'], axis=1)
test_SED_df = test_SED_df.drop(['着順', '年月日'], axis=1)

# 学習データとテストデータの確認
print('Training SED_df shape:', train_SED_df.shape)
print('Test SED_df shape:', test_SED_df.shape)
# Out:
# Training SED_df shape: (38168, 83)
# Test SED_df shape: (9543, 83)

# %%
# カラムのデータ型を確認
print(train_SED_df.dtypes)
# Out:
# レースキー         int32
# 場コード          int64
# 年             int64
# 回             int64
# 日             int32
#              ...
# 収得賞金        float64
# レースペース流れ    float64
# 馬ペース流れ      float64
# 4角コース取り     float64
# target        int64
# Length: 83, dtype: object

# %%
# カテゴリカル変数の特定

categorical_cols = train_SED_df.select_dtypes(include=['object']).columns

# テキストデータの特定
# ここでは、テキストデータがどのカラムに含まれているかをユーザーからの指示に基づいて判断します。

# 数値変数の特定
numeric_cols = train_SED_df.select_dtypes(include=['int64', 'float64']).columns

# カテゴリカル変数のワンホットエンコーディング
train_SED_df = pd.get_dummies(train_SED_df, columns=categorical_cols)
test_SED_df = pd.get_dummies(test_SED_df, columns=categorical_cols)


# 数値変数の標準化（必要に応じて）
# ここでは、標準化の必要性をユーザーからの指示に基づいて判断します。

# 前処理後のデータの確認
print('Training data shape after preprocessing:', train_SED_df.shape)
print('Test data shape after preprocessing:', test_SED_df.shape)
# Out:
# Training data shape after preprocessing: (38168, 83)
# Test data shape after preprocessing: (9543, 83)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import f1_score, roc_auc_score



# データの分割
X_train, X_test, y_train, y_test = train_test_split(train_SED_df.drop(['target'], axis=1), train_SED_df['target'], test_size=0.2, random_state=42)

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'learning_rate': 0.05,
    'num_leaves': 31,
    'max_depth': -1,
    'min_child_samples': 20,
    'max_bin': 255,
    'verbose': -1
}

# モデルのトレーニング
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

gbm = lgb.train(params, lgb_train, num_boost_round=500, valid_sets=lgb_eval, early_stopping_rounds=20)

# モデルの評価
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# 予測値を二値に変換
y_pred_binary = (y_pred >= 0.5).astype(int)
f1 = f1_score(y_test, y_pred_binary)
auc = roc_auc_score(y_test, y_pred)

# 評価指標の表示
print(f'F1 Score: {f1}')
print(f'AUC Score: {auc}')
# Out:
# c:\Users\rebor\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's binary_logloss: 0.496756
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_logloss: 0.455314
# [3]	valid_0's binary_logloss: 0.419649
# [4]	valid_0's binary_logloss: 0.388544
# [5]	valid_0's binary_logloss: 0.361073
# [6]	valid_0's binary_logloss: 0.33646
# [7]	valid_0's binary_logloss: 0.31414
# [8]	valid_0's binary_logloss: 0.293966
# [9]	valid_0's binary_logloss: 0.275523
# [10]	valid_0's binary_logloss: 0.258533
# [11]	valid_0's binary_logloss: 0.24289
# [12]	valid_0's binary_logloss: 0.228394
# [13]	valid_0's binary_logloss: 0.215057
# [14]	valid_0's binary_logloss: 0.202686
# [15]	valid_0's binary_logloss: 0.191173
# [16]	valid_0's binary_logloss: 0.180344
# [17]	valid_0's binary_logloss: 0.170294
# [18]	valid_0's binary_logloss: 0.160932
# [19]	valid_0's binary_logloss: 0.152155
# [20]	valid_0's binary_logloss: 0.143943
# [21]	valid_0's binary_logloss: 0.136143
# [22]	valid_0's binary_logloss: 0.128886
# [23]	valid_0's binary_logloss: 0.122075
# [24]	valid_0's binary_logloss: 0.11568
# [25]	valid_0's binary_logloss: 0.109596
# [26]	valid_0's binary_logloss: 0.10384
# [27]	valid_0's binary_logloss: 0.0984837
# [28]	valid_0's binary_logloss: 0.0934114
# [29]	valid_0's binary_logloss: 0.088575
# [30]	valid_0's binary_logloss: 0.0840769
# [31]	valid_0's binary_logloss: 0.0798399
# [32]	valid_0's binary_logloss: 0.0757582
# [33]	valid_0's binary_logloss: 0.0719669
# [34]	valid_0's binary_logloss: 0.0683284
# [35]	valid_0's binary_logloss: 0.0648869
# [36]	valid_0's binary_logloss: 0.0616209
# [37]	valid_0's binary_logloss: 0.0585351
# [38]	valid_0's binary_logloss: 0.0556365
# [39]	valid_0's binary_logloss: 0.052888
# [40]	valid_0's binary_logloss: 0.0502874
# [41]	valid_0's binary_logloss: 0.0478192
# [42]	valid_0's binary_logloss: 0.0454953
# [43]	valid_0's binary_logloss: 0.0433047
# [44]	valid_0's binary_logloss: 0.0411778
# [45]	valid_0's binary_logloss: 0.0391822
# [46]	valid_0's binary_logloss: 0.0372683
# [47]	valid_0's binary_logloss: 0.0354587
# [48]	valid_0's binary_logloss: 0.0337353
# [49]	valid_0's binary_logloss: 0.0321081
# [50]	valid_0's binary_logloss: 0.0305424
# [51]	valid_0's binary_logloss: 0.0290695
# [52]	valid_0's binary_logloss: 0.0276887
# [53]	valid_0's binary_logloss: 0.0263378
# [54]	valid_0's binary_logloss: 0.025077
# [55]	valid_0's binary_logloss: 0.023875
# [56]	valid_0's binary_logloss: 0.0227644
# [57]	valid_0's binary_logloss: 0.0216832
# [58]	valid_0's binary_logloss: 0.0206695
# [59]	valid_0's binary_logloss: 0.0196933
# [60]	valid_0's binary_logloss: 0.0187981
# [61]	valid_0's binary_logloss: 0.0179506
# [62]	valid_0's binary_logloss: 0.0171045
# [63]	valid_0's binary_logloss: 0.0163189
# [64]	valid_0's binary_logloss: 0.0155845
# [65]	valid_0's binary_logloss: 0.0148973
# [66]	valid_0's binary_logloss: 0.0142218
# [67]	valid_0's binary_logloss: 0.0135704
# [68]	valid_0's binary_logloss: 0.0129606
# [69]	valid_0's binary_logloss: 0.0123895
# [70]	valid_0's binary_logloss: 0.0118368
# [71]	valid_0's binary_logloss: 0.0113134
# [72]	valid_0's binary_logloss: 0.0108092
# [73]	valid_0's binary_logloss: 0.0103487
# [74]	valid_0's binary_logloss: 0.00989255
# [75]	valid_0's binary_logloss: 0.00946249
# [76]	valid_0's binary_logloss: 0.00905021
# [77]	valid_0's binary_logloss: 0.00865967
# [78]	valid_0's binary_logloss: 0.00825363
# [79]	valid_0's binary_logloss: 0.00790471
# [80]	valid_0's binary_logloss: 0.00757201
# [81]	valid_0's binary_logloss: 0.00721969
# [82]	valid_0's binary_logloss: 0.00691653
# [83]	valid_0's binary_logloss: 0.00664326
# [84]	valid_0's binary_logloss: 0.00633486
# [85]	valid_0's binary_logloss: 0.00606997
# [86]	valid_0's binary_logloss: 0.00578946
# [87]	valid_0's binary_logloss: 0.00555699
# [88]	valid_0's binary_logloss: 0.0053363
# [89]	valid_0's binary_logloss: 0.00509195
# [90]	valid_0's binary_logloss: 0.00489101
# [91]	valid_0's binary_logloss: 0.00469611
# [92]	valid_0's binary_logloss: 0.00448338
# [93]	valid_0's binary_logloss: 0.00429783
# [94]	valid_0's binary_logloss: 0.00413869
# [95]	valid_0's binary_logloss: 0.00398959
# [96]	valid_0's binary_logloss: 0.00384225
# [97]	valid_0's binary_logloss: 0.00370749
# [98]	valid_0's binary_logloss: 0.00357508
# [99]	valid_0's binary_logloss: 0.00343254
# [100]	valid_0's binary_logloss: 0.00330741
# [101]	valid_0's binary_logloss: 0.00317123
# [102]	valid_0's binary_logloss: 0.00305273
# [103]	valid_0's binary_logloss: 0.00295193
# [104]	valid_0's binary_logloss: 0.002833
# [105]	valid_0's binary_logloss: 0.00272485
# [106]	valid_0's binary_logloss: 0.00263962
# [107]	valid_0's binary_logloss: 0.00256015
# [108]	valid_0's binary_logloss: 0.0024842
# [109]	valid_0's binary_logloss: 0.0024093
# [110]	valid_0's binary_logloss: 0.00233413
# [111]	valid_0's binary_logloss: 0.00226538
# [112]	valid_0's binary_logloss: 0.00220336
# [113]	valid_0's binary_logloss: 0.0021437
# [114]	valid_0's binary_logloss: 0.0020876
# [115]	valid_0's binary_logloss: 0.00204119
# [116]	valid_0's binary_logloss: 0.00199191
# [117]	valid_0's binary_logloss: 0.00194026
# [118]	valid_0's binary_logloss: 0.00189204
# [119]	valid_0's binary_logloss: 0.00185105
# [120]	valid_0's binary_logloss: 0.00178348
# [121]	valid_0's binary_logloss: 0.0017246
# [122]	valid_0's binary_logloss: 0.00168791
# [123]	valid_0's binary_logloss: 0.00165867
# [124]	valid_0's binary_logloss: 0.00160994
# [125]	valid_0's binary_logloss: 0.00157521
# [126]	valid_0's binary_logloss: 0.00155044
# [127]	valid_0's binary_logloss: 0.0015282
# [128]	valid_0's binary_logloss: 0.00147585
# [129]	valid_0's binary_logloss: 0.00143005
# [130]	valid_0's binary_logloss: 0.00141234
# [131]	valid_0's binary_logloss: 0.00137939
# [132]	valid_0's binary_logloss: 0.00136482
# [133]	valid_0's binary_logloss: 0.00134608
# [134]	valid_0's binary_logloss: 0.00131711
# [135]	valid_0's binary_logloss: 0.00130644
# [136]	valid_0's binary_logloss: 0.00125666
# [137]	valid_0's binary_logloss: 0.00122779
# [138]	valid_0's binary_logloss: 0.0012037
# [139]	valid_0's binary_logloss: 0.00117817
# [140]	valid_0's binary_logloss: 0.00115207
# [141]	valid_0's binary_logloss: 0.00110815
# [142]	valid_0's binary_logloss: 0.00108881
# [143]	valid_0's binary_logloss: 0.00106885
# [144]	valid_0's binary_logloss: 0.00105432
# [145]	valid_0's binary_logloss: 0.00104638
# [146]	valid_0's binary_logloss: 0.00103661
# [147]	valid_0's binary_logloss: 0.00103058
# [148]	valid_0's binary_logloss: 0.00102106
# [149]	valid_0's binary_logloss: 0.00102231
# [150]	valid_0's binary_logloss: 0.00102108
# [151]	valid_0's binary_logloss: 0.00101321
# [152]	valid_0's binary_logloss: 0.00101481
# [153]	valid_0's binary_logloss: 0.00101757
# [154]	valid_0's binary_logloss: 0.0010144
# [155]	valid_0's binary_logloss: 0.00100135
# [156]	valid_0's binary_logloss: 0.00099542
# [157]	valid_0's binary_logloss: 0.000990319
# [158]	valid_0's binary_logloss: 0.000983212
# [159]	valid_0's binary_logloss: 0.000976989
# [160]	valid_0's binary_logloss: 0.000984922
# [161]	valid_0's binary_logloss: 0.00098206
# [162]	valid_0's binary_logloss: 0.000988674
# [163]	valid_0's binary_logloss: 0.000995834
# [164]	valid_0's binary_logloss: 0.00099413
# [165]	valid_0's binary_logloss: 0.00100051
# [166]	valid_0's binary_logloss: 0.00100296
# [167]	valid_0's binary_logloss: 0.000990283
# [168]	valid_0's binary_logloss: 0.000984962
# [169]	valid_0's binary_logloss: 0.000980649
# [170]	valid_0's binary_logloss: 0.000980521
# [171]	valid_0's binary_logloss: 0.000993385
# [172]	valid_0's binary_logloss: 0.000985867
# [173]	valid_0's binary_logloss: 0.000994813
# [174]	valid_0's binary_logloss: 0.000989598
# [175]	valid_0's binary_logloss: 0.000997785
# [176]	valid_0's binary_logloss: 0.000992936
# [177]	valid_0's binary_logloss: 0.00100346
# [178]	valid_0's binary_logloss: 0.00101475
# [179]	valid_0's binary_logloss: 0.00099629
# Early stopping, best iteration is:
# [159]	valid_0's binary_logloss: 0.000976989
# F1 Score: 0.9991682838924314
# AUC Score: 0.9999995242292895
